# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
from tensorflow.keras import layers
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 
import string
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import PIL
import random
import time
from pathlib import Path

import re
from IPython import display

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Restrict TensorFlow to only use the first GPU
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')

        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763478550.257210    1196 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5561 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# <h2> Preprocess Text </h2>

# %%
dictionary_path = './dictionary'
vocab = np.load(dictionary_path + '/vocab.npy')
print('there are {} vocabularies in total'.format(len(vocab)))

word2Id_dict = dict(np.load(dictionary_path + '/word2Id.npy'))
id2word_dict = dict(np.load(dictionary_path + '/id2Word.npy'))
print('Word to id mapping, for example: %s -> %s' % ('flower', word2Id_dict['flower']))
print('Id to word mapping, for example: %s -> %s' % ('1', id2word_dict['1']))
print('Tokens: <PAD>: %s; <RARE>: %s' % (word2Id_dict['<PAD>'], word2Id_dict['<RARE>']))
# Out:
# there are 5427 vocabularies in total
# Word to id mapping, for example: flower -> 1
# Id to word mapping, for example: 1 -> flower
# Tokens: <PAD>: 5427; <RARE>: 5428
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def sent2IdList(line, MAX_SEQ_LENGTH=20):
    MAX_SEQ_LIMIT = MAX_SEQ_LENGTH
    padding = 0
    
    # data preprocessing, remove all puntuation in the texts
    prep_line = re.sub('[%s]' % re.escape(string.punctuation), ' ', line.rstrip())
    prep_line = prep_line.replace('-', ' ')
    prep_line = prep_line.replace('-', ' ')
    prep_line = prep_line.replace('  ', ' ')
    prep_line = prep_line.replace('.', '')
    tokens = prep_line.split(' ')
    tokens = [
        tokens[i] for i in range(len(tokens))
        if tokens[i] != ' ' and tokens[i] != ''
    ]
    l = len(tokens)
    padding = MAX_SEQ_LIMIT - l
    
    # make sure length of each text is equal to MAX_SEQ_LENGTH, and replace the less common word with <RARE> token
    for i in range(padding):
        tokens.append('<PAD>')
    line = [
        word2Id_dict[tokens[k]]
        if tokens[k] in word2Id_dict else word2Id_dict['<RARE>']
        for k in range(len(tokens))
    ]

    return line

text = "the flower shown has yellow anther red pistil and bright red petals."
print(text)
print(sent2IdList(text))
# Out:
# the flower shown has yellow anther red pistil and bright red petals.
# [np.str_('9'), np.str_('1'), np.str_('82'), np.str_('5'), np.str_('11'), np.str_('70'), np.str_('20'), np.str_('31'), np.str_('3'), np.str_('29'), np.str_('20'), np.str_('2'), np.str_('5427'), np.str_('5427'), np.str_('5427'), np.str_('5427'), np.str_('5427'), np.str_('5427'), np.str_('5427'), np.str_('5427')]
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# <h2> Dataset</h2>

# %%
data_path = './dataset'
df = pd.read_pickle(data_path + '/text2ImgData.pkl')
num_training_sample = len(df)
n_images_train = num_training_sample
print('There are %d image in training data' % (n_images_train))
# Out:
# There are 7370 image in training data

# %% [markdown]
# <h2>Create Dataset by Dataset API </h2>

# %%
# in this competition, you have to generate image in size 64x64x3
IMAGE_HEIGHT = 64
IMAGE_WIDTH = 64
IMAGE_CHANNEL = 3
IMAGE_SIZE_CROPPED = 32

def training_data_generator(caption, image_path):
    # load in the image according to image path
    img = tf.io.read_file(image_path)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img.set_shape([None, None, 3])
    img = tf.image.resize(img, size=[IMAGE_HEIGHT, IMAGE_WIDTH])
    img.set_shape([IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNEL])

    distorted_image = tf.image.random_crop(img, [IMAGE_SIZE_CROPPED,IMAGE_SIZE_CROPPED,IMAGE_CHANNEL])
    distorted_image = tf.image.resize(distorted_image, [IMAGE_HEIGHT, IMAGE_WIDTH])
    distorted_image = tf.image.random_flip_left_right(distorted_image)
    distorted_image = tf.image.random_brightness(distorted_image, max_delta=0.2)
    distorted_image = tf.image.random_contrast(distorted_image, lower=0.8, upper=1.2)
    distorted_image = tf.image.per_image_standardization(distorted_image)
    distorted_image = tf.clip_by_value(distorted_image, 0.0, 1.0)

    caption = tf.cast(caption, tf.int32)

    return distorted_image, caption

def dataset_generator(filenames, batch_size, data_generator):
    # load the training data into two NumPy arrays
    df = pd.read_pickle(filenames)
    captions = df['Captions'].values
    caption = []
    # each image has 1 to 10 corresponding captions
    # we choose one of them randomly for training
    for i in range(len(captions)):
        caption.append(random.choice(captions[i]))
    caption = np.asarray(caption)
    caption = caption.astype(int)
    image_path = df['ImagePath'].values
    
    # assume that each row of `features` corresponds to the same row as `labels`.
    assert caption.shape[0] == image_path.shape[0]
    
    dataset = tf.data.Dataset.from_tensor_slices((caption, image_path))
    dataset = dataset.map(data_generator, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.shuffle(len(caption)).batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    return dataset

# %%
BATCH_SIZE = 64
dataset = dataset_generator(data_path + '/text2ImgData.pkl', BATCH_SIZE, training_data_generator)

# %% [markdown]
# <h1> Conditional GAN Model </h1>

# %% [markdown]
# <h2> Text Encoder </h2>
# A RNN encoder that captures the meaning of input text.
#
# Input: text, which is a list of ids. <br>
# Output: embedding, or hidden representation of input text.

# %%
class TextEncoder(tf.keras.Model):
    """
    Encode text (a caption) into hidden representation
    input: text, which is a list of ids
    output: embedding, or hidden representation of input text in dimension of RNN_HIDDEN_SIZE
    """
    def __init__(self, hparas):
        super(TextEncoder, self).__init__()
        self.hparas = hparas
        self.batch_size = self.hparas['BATCH_SIZE']
        
        # embedding with tensorflow API
        self.embedding = layers.Embedding(self.hparas['VOCAB_SIZE'], self.hparas['EMBED_DIM'])
        # RNN, here we use GRU cell, another common RNN cell similar to LSTM
        self.gru = layers.GRU(self.hparas['RNN_HIDDEN_SIZE'],
                              return_sequences=True,
                              return_state=True,
                              recurrent_initializer='glorot_uniform')
    
    def call(self, text, hidden):
        text = self.embedding(text)
        output, state = self.gru(text, initial_state = hidden)
        return output[:, -1, :], state
    
    def initialize_hidden_state(self):
        return tf.zeros((self.hparas['BATCH_SIZE'], self.hparas['RNN_HIDDEN_SIZE']))

# %% [markdown]
# <h2> Generator</h2>
# A image generator which generates the target image illustrating the input text.
#
# Input: hidden representation of input text and random noise z with random seed. <br>
# Output: target image, which is conditioned on the given text, in size 64x64x3.

# %%
class Generator(tf.keras.Model):
    """
    Generate fake image based on given text(hidden representation) and noise z
    input: text and noise
    output: fake image with size 64*64*3
    """
    def __init__(self, hparas):
        super(Generator, self).__init__()
        self.hparas = hparas
        self.flatten = tf.keras.layers.Flatten()
        self.d1 = tf.keras.layers.Dense(self.hparas['DENSE_DIM'])
        self.d2 = tf.keras.layers.Dense(64*64*3)
        
    def call(self, text, noise_z):
        text = self.flatten(text)
        text = self.d1(text)
        text = tf.nn.leaky_relu(text)
        
        # concatenate input text and random noise
        text_concat = tf.concat([noise_z, text], axis=1)
        text_concat = self.d2(text_concat)
        
        logits = tf.reshape(text_concat, [-1, 64, 64, 3])
        output = tf.nn.tanh(logits)
        
        return logits, output

# %% [markdown]
# <h2>Discriminator</h2>
# A binary classifier which can discriminate the real and fake image:
#
# 1. Real image
#     - Input: real image and the paired text
#     - Output: a floating number representing the result, which is expected to be 1.
# 2. Fake Image
#     - Input: generated image and paired text
#     - Output: a floating number representing the result, which is expected to be 0.

# %%
class Discriminator(tf.keras.Model):
    """
    Differentiate the real and fake image
    input: image and corresponding text
    output: labels, the real image should be 1, while the fake should be 0
    """
    def __init__(self, hparas):
        super(Discriminator, self).__init__()
        self.hparas = hparas
        self.flatten = tf.keras.layers.Flatten()
        self.d_text = tf.keras.layers.Dense(self.hparas['DENSE_DIM'])
        self.d_img = tf.keras.layers.Dense(self.hparas['DENSE_DIM'])
        self.d = tf.keras.layers.Dense(1)
    
    def call(self, img, text):
        text = self.flatten(text)
        text = self.d_text(text)
        text = tf.nn.leaky_relu(text)
        
        img = self.flatten(img)
        img = self.d_img(img)
        img = tf.nn.leaky_relu(img)
        
        # concatenate image with paired text
        img_text = tf.concat([text, img], axis=1)
        
        logits = self.d(img_text)
        output = tf.nn.sigmoid(logits)
        
        return logits, output

# %%
hparas = {
    'MAX_SEQ_LENGTH': 20,                     # maximum sequence length
    'EMBED_DIM': 256,                         # word embedding dimension
    'VOCAB_SIZE': len(word2Id_dict),          # size of dictionary of captions
    'RNN_HIDDEN_SIZE': 128,                   # number of RNN neurons
    'Z_DIM': 512,                             # random noise z dimension
    'DENSE_DIM': 128,                         # number of neurons in dense layer
    'IMAGE_SIZE': [64, 64, 3],                # render image size
    'BATCH_SIZE': 64,
    'LR': 1e-4,
    'LR_DECAY': 0.5,
    'BETA_1': 0.5,
    'N_EPOCH': 500,                            # number of epoch for demo
    'N_SAMPLE': num_training_sample,          # size of training data
    'CHECKPOINTS_DIR': './checkpoints/demo',  # checkpoint path
    'PRINT_FREQ': 1                           # printing frequency of loss
}

# %%
text_encoder = TextEncoder(hparas)
generator = Generator(hparas)
discriminator = Discriminator(hparas)

# %% [markdown]
# <h2> Loss Function and Optimization </h2>
# Although the conditional GAN model is quite complex, the loss function used to optimize the network is relatively simple. Actually, it is simply a binary classification task, thus we use cross entropy as our loss.

# %%
# This method returns a helper function to compute cross entropy loss
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
def discriminator_loss(real_logits, fake_logits):
    # output value of real image should be 1
    real_loss = cross_entropy(tf.ones_like(real_logits), real_logits)
    # output value of fake image should be 0
    fake_loss = cross_entropy(tf.zeros_like(fake_logits), fake_logits)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    # output value of fake image should be 0
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
# we use seperated optimizers for training generator and discriminator
generator_optimizer = tf.keras.optimizers.Adam(hparas['LR'])
discriminator_optimizer = tf.keras.optimizers.Adam(hparas['LR'])

# %%
# one benefit of tf.train.Checkpoint() API is we can save everything seperately
checkpoint_dir = hparas['CHECKPOINTS_DIR']
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 text_encoder=text_encoder,
                                 generator=generator,
                                 discriminator=discriminator)

# %%
@tf.function
def train_step(real_image, caption, hidden):
    # random noise for generator
    noise = tf.random.normal(shape=[hparas['BATCH_SIZE'], hparas['Z_DIM']], mean=0.0, stddev=1.0)
    
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        text_embed, hidden = text_encoder(caption, hidden)
        _, fake_image = generator(text_embed, noise)
        real_logits, real_output = discriminator(real_image, text_embed)
        fake_logits, fake_output = discriminator(fake_image, text_embed)

        g_loss = generator_loss(fake_logits)
        d_loss = discriminator_loss(real_logits, fake_logits)

    grad_g = gen_tape.gradient(g_loss, generator.trainable_variables)
    grad_d = disc_tape.gradient(d_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(grad_g, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(grad_d, discriminator.trainable_variables))
    
    return g_loss, d_loss

# %%
@tf.function
def test_step(caption, noise, hidden):
    text_embed, hidden = text_encoder(caption, hidden)
    _, fake_image = generator(text_embed, noise)
    return fake_image

# %% [markdown]
# <h2> Visualiztion </h2>
# During training, we can visualize the generated image to evaluate the quality of generator. The followings are some functions helping visualization.

# %%
def merge(images, size):
    h, w = images.shape[1], images.shape[2]
    img = np.zeros((h * size[0], w * size[1], 3))
    for idx, image in enumerate(images):
        i = idx % size[1]
        j = idx // size[1]
        img[j*h:j*h+h, i*w:i*w+w, :] = image
    return img

def imsave(images, size, path):
    # getting the pixel values between [0, 1] to save it
    return plt.imsave(path, merge(images, size)*0.5 + 0.5)

def save_images(images, size, image_path):
    return imsave(images, size, image_path)

# %%
def sample_generator(caption, batch_size):
    caption = np.asarray(caption)
    caption = caption.astype(int)
    dataset = tf.data.Dataset.from_tensor_slices(caption)
    dataset = dataset.batch(batch_size)
    return dataset

# %% [markdown]
# We always use same random seed and same senteces during training, which is more convenient for us to evaluate the quality of generated image.

# %%
ni = int(np.ceil(np.sqrt(hparas['BATCH_SIZE'])))
sample_size = hparas['BATCH_SIZE']
sample_seed = np.random.normal(loc=0.0, scale=1.0, size=(sample_size, hparas['Z_DIM'])).astype(np.float32)
sample_sentence = ["the flower shown has yellow anther red pistil and bright red petals."] * int(sample_size/ni) + \
                  ["this flower has petals that are yellow, white and purple and has dark lines"] * int(sample_size/ni) + \
                  ["the petals on this flower are white with a yellow center"] * int(sample_size/ni) + \
                  ["this flower has a lot of small round pink petals."] * int(sample_size/ni) + \
                  ["this flower is orange in color, and has petals that are ruffled and rounded."] * int(sample_size/ni) + \
                  ["the flower has yellow petals and the center of it is brown."] * int(sample_size/ni) + \
                  ["this flower has petals that are blue and white."] * int(sample_size/ni) +\
                  ["these white flowers have petals that start off white in color and end in a white towards the tips."] * int(sample_size/ni)

for i, sent in enumerate(sample_sentence):
    sample_sentence[i] = sent2IdList(sent)
sample_sentence = sample_generator(sample_sentence, hparas['BATCH_SIZE'])

# %% [markdown]
# <h2> Training</h2>

# %%
if not os.path.exists('samples/demo'):
    os.makedirs('samples/demo')

# %%
def train(dataset, epochs):
    # hidden state of RNN
    hidden = text_encoder.initialize_hidden_state()
    steps_per_epoch = int(hparas['N_SAMPLE']/hparas['BATCH_SIZE'])
    
    for epoch in range(hparas['N_EPOCH']):
        g_total_loss = 0
        d_total_loss = 0
        start = time.time()
        
        for image, caption in dataset:
            g_loss, d_loss = train_step(image, caption, hidden)
            g_total_loss += g_loss
            d_total_loss += d_loss
            
        time_tuple = time.localtime()
        time_string = time.strftime("%m/%d/%Y, %H:%M:%S", time_tuple)
            
        print("Epoch {}, gen_loss: {:.4f}, disc_loss: {:.4f}".format(epoch+1,
                                                                     g_total_loss/steps_per_epoch,
                                                                     d_total_loss/steps_per_epoch))
        print('Time for epoch {} is {:.4f} sec'.format(epoch+1, time.time()-start))
        
        # save the model
        if (epoch + 1) % 50 == 0:
            checkpoint.save(file_prefix = checkpoint_prefix)
        
        # visualization
        if (epoch + 1) % hparas['PRINT_FREQ'] == 0:
            for caption in sample_sentence:
                fake_image = test_step(caption, sample_seed, hidden)
            save_images(fake_image, [ni, ni], 'samples/demo/train_{:02d}.jpg'.format(epoch))

# %%
train(dataset, hparas['N_EPOCH'])
# Out:
# Epoch 1, gen_loss: 0.4744, disc_loss: 1.0821
# Time for epoch 1 is 13.0698 sec
# Epoch 2, gen_loss: 0.5088, disc_loss: 1.0445
# Time for epoch 2 is 10.1853 sec
# 2025-11-18 23:47:28.651011: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:24: Filling up shuffle buffer (this may take a while): 6454 of 7370
# 2025-11-18 23:47:29.588771: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:483] Shuffle buffer filled.
# Epoch 3, gen_loss: 0.7372, disc_loss: 0.8094
# Time for epoch 3 is 12.1837 sec
# Epoch 4, gen_loss: 1.2155, disc_loss: 0.4767
# Time for epoch 4 is 9.0302 sec
# Epoch 5, gen_loss: 2.1637, disc_loss: 0.1637
# Time for epoch 5 is 8.6122 sec
# Epoch 6, gen_loss: 1.8494, disc_loss: 0.2246
# Time for epoch 6 is 8.5663 sec
# 2025-11-18 23:47:57.282643: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 7, gen_loss: 2.2657, disc_loss: 0.1518
# Time for epoch 7 is 6.2509 sec
# Epoch 8, gen_loss: 2.4750, disc_loss: 0.1345
# Time for epoch 8 is 5.9473 sec
# Epoch 9, gen_loss: 3.3259, disc_loss: 0.0817
# Time for epoch 9 is 6.2755 sec
# Epoch 10, gen_loss: 3.1633, disc_loss: 0.1257
# Time for epoch 10 is 6.3384 sec
# Epoch 11, gen_loss: 3.6073, disc_loss: 0.1250
# Time for epoch 11 is 5.8538 sec
# Epoch 12, gen_loss: 3.4676, disc_loss: 0.2188
# Time for epoch 12 is 9.3209 sec
# Epoch 13, gen_loss: 3.7564, disc_loss: 0.2967
# Time for epoch 13 is 6.2543 sec
# Epoch 14, gen_loss: 3.2343, disc_loss: 0.4113
# Time for epoch 14 is 6.3133 sec
# Epoch 15, gen_loss: 3.1046, disc_loss: 0.5961
# Time for epoch 15 is 5.8222 sec
# Epoch 16, gen_loss: 3.6075, disc_loss: 0.6133
# Time for epoch 16 is 5.8780 sec
# Epoch 17, gen_loss: 3.5659, disc_loss: 0.5888
# Time for epoch 17 is 9.1776 sec
# Epoch 18, gen_loss: 3.0460, disc_loss: 0.8053
# Time for epoch 18 is 6.1880 sec
# Epoch 19, gen_loss: 2.6490, disc_loss: 0.8931
# Time for epoch 19 is 6.4511 sec
# Epoch 20, gen_loss: 2.4031, disc_loss: 0.9398
# Time for epoch 20 is 5.8802 sec
# Epoch 21, gen_loss: 2.7770, disc_loss: 0.8304
# Time for epoch 21 is 6.2839 sec
# Epoch 22, gen_loss: 2.8869, disc_loss: 0.6833
# Time for epoch 22 is 9.1895 sec
# 2025-11-18 23:49:45.446332: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 23, gen_loss: 2.8307, disc_loss: 0.6429
# Time for epoch 23 is 7.7397 sec
# Epoch 24, gen_loss: 2.7131, disc_loss: 0.5649
# Time for epoch 24 is 7.0300 sec
# Epoch 25, gen_loss: 2.5156, disc_loss: 0.5978
# Time for epoch 25 is 7.0146 sec
# Epoch 26, gen_loss: 2.3961, disc_loss: 0.6570
# Time for epoch 26 is 8.8056 sec
# Epoch 27, gen_loss: 2.3936, disc_loss: 0.6855
# Time for epoch 27 is 6.9505 sec
# Epoch 28, gen_loss: 2.1838, disc_loss: 0.7968
# Time for epoch 28 is 7.0657 sec
# Epoch 29, gen_loss: 2.5868, disc_loss: 0.6139
# Time for epoch 29 is 6.5204 sec
# Epoch 30, gen_loss: 2.5624, disc_loss: 0.6878
# Time for epoch 30 is 6.8514 sec
# Epoch 31, gen_loss: 2.8060, disc_loss: 0.5265
# Time for epoch 31 is 9.5227 sec
# Epoch 32, gen_loss: 2.2354, disc_loss: 0.6818
# Time for epoch 32 is 6.9282 sec
# Epoch 33, gen_loss: 2.1495, disc_loss: 0.5810
# Time for epoch 33 is 6.8299 sec
# Epoch 34, gen_loss: 1.3416, disc_loss: 0.7964
# Time for epoch 34 is 6.2176 sec
# Epoch 35, gen_loss: 1.3697, disc_loss: 0.6988
# Time for epoch 35 is 7.7947 sec
# Epoch 36, gen_loss: 1.0814, disc_loss: 0.8341
# Time for epoch 36 is 8.3542 sec
# Epoch 37, gen_loss: 1.0027, disc_loss: 0.8472
# Time for epoch 37 is 6.7600 sec
# Epoch 38, gen_loss: 0.9813, disc_loss: 0.9189
# Time for epoch 38 is 6.9361 sec
# Epoch 39, gen_loss: 0.9723, disc_loss: 1.0420
# Time for epoch 39 is 6.7130 sec
# Epoch 40, gen_loss: 0.9652, disc_loss: 1.1853
# Time for epoch 40 is 6.0603 sec
# Epoch 41, gen_loss: 0.9506, disc_loss: 1.3151
# Time for epoch 41 is 8.1293 sec
# Epoch 42, gen_loss: 0.9867, disc_loss: 1.3361
# Time for epoch 42 is 6.0640 sec
# Epoch 43, gen_loss: 1.0274, disc_loss: 1.3793
# Time for epoch 43 is 6.2044 sec
# Epoch 44, gen_loss: 1.2368, disc_loss: 1.2461
# Time for epoch 44 is 5.9791 sec
# Epoch 45, gen_loss: 1.5782, disc_loss: 1.0296
# Time for epoch 45 is 5.9604 sec
# Epoch 46, gen_loss: 1.8245, disc_loss: 0.9335
# Time for epoch 46 is 8.2889 sec
# Epoch 47, gen_loss: 2.1645, disc_loss: 0.6903
# Time for epoch 47 is 6.3553 sec
# Epoch 48, gen_loss: 1.9018, disc_loss: 0.7157
# Time for epoch 48 is 6.4253 sec
# Epoch 49, gen_loss: 1.7779, disc_loss: 0.6339
# Time for epoch 49 is 6.6703 sec
# Epoch 50, gen_loss: 1.3773, disc_loss: 0.7819
# Time for epoch 50 is 6.3935 sec
# Epoch 51, gen_loss: 1.3097, disc_loss: 0.8417
# Time for epoch 51 is 8.7077 sec
# Epoch 52, gen_loss: 1.1632, disc_loss: 0.9866
# Time for epoch 52 is 6.3363 sec
# Epoch 53, gen_loss: 1.2411, disc_loss: 0.9644
# Time for epoch 53 is 6.4214 sec
# Epoch 54, gen_loss: 1.1399, disc_loss: 1.0573
# Time for epoch 54 is 6.2161 sec
# 2025-11-18 23:53:32.227630: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 55, gen_loss: 1.2459, disc_loss: 1.0362
# Time for epoch 55 is 5.9513 sec
# Epoch 56, gen_loss: 1.1941, disc_loss: 1.1944
# Time for epoch 56 is 9.0275 sec
# Epoch 57, gen_loss: 1.2770, disc_loss: 1.0603
# Time for epoch 57 is 6.6623 sec
# Epoch 58, gen_loss: 1.3282, disc_loss: 1.0069
# Time for epoch 58 is 5.8260 sec
# Epoch 59, gen_loss: 1.2671, disc_loss: 1.1458
# Time for epoch 59 is 6.5665 sec
# Epoch 60, gen_loss: 1.4645, disc_loss: 1.0229
# Time for epoch 60 is 6.6010 sec
# Epoch 61, gen_loss: 1.7480, disc_loss: 0.8756
# Time for epoch 61 is 9.4505 sec
# Epoch 62, gen_loss: 1.7490, disc_loss: 0.8418
# Time for epoch 62 is 6.3509 sec
# Epoch 63, gen_loss: 1.9214, disc_loss: 0.6115
# Time for epoch 63 is 6.1128 sec
# Epoch 64, gen_loss: 1.7322, disc_loss: 0.6158
# Time for epoch 64 is 6.2754 sec
# Epoch 65, gen_loss: 1.8946, disc_loss: 0.5795
# Time for epoch 65 is 6.3628 sec
# Epoch 66, gen_loss: 1.8037, disc_loss: 0.6154
# Time for epoch 66 is 8.3870 sec
# Epoch 67, gen_loss: 1.7925, disc_loss: 0.7135
# Time for epoch 67 is 6.3203 sec
# Epoch 68, gen_loss: 1.7226, disc_loss: 0.7435
# Time for epoch 68 is 6.1534 sec
# Epoch 69, gen_loss: 1.6663, disc_loss: 0.7850
# Time for epoch 69 is 6.0703 sec
# Epoch 70, gen_loss: 1.5576, disc_loss: 0.8431
# Time for epoch 70 is 6.3781 sec
# Epoch 71, gen_loss: 1.6270, disc_loss: 0.8408
# Time for epoch 71 is 8.6998 sec
# Epoch 72, gen_loss: 1.5642, disc_loss: 0.9440
# Time for epoch 72 is 6.4673 sec
# Epoch 73, gen_loss: 1.5640, disc_loss: 0.9556
# Time for epoch 73 is 6.1286 sec
# Epoch 74, gen_loss: 1.6986, disc_loss: 0.9214
# Time for epoch 74 is 6.4311 sec
# Epoch 75, gen_loss: 1.6366, disc_loss: 0.9008
# Time for epoch 75 is 6.0042 sec
# Epoch 76, gen_loss: 1.6321, disc_loss: 0.8497
# Time for epoch 76 is 8.5456 sec
# Epoch 77, gen_loss: 1.5387, disc_loss: 0.8412
# Time for epoch 77 is 6.4355 sec
# Epoch 78, gen_loss: 1.4850, disc_loss: 0.9152
# Time for epoch 78 is 6.3989 sec
# Epoch 79, gen_loss: 1.5324, disc_loss: 0.9449
# Time for epoch 79 is 6.1417 sec
# Epoch 80, gen_loss: 1.4287, disc_loss: 0.9997
# Time for epoch 80 is 6.0203 sec
# Epoch 81, gen_loss: 1.3894, disc_loss: 1.1213
# Time for epoch 81 is 10.9247 sec
# Epoch 82, gen_loss: 1.4424, disc_loss: 1.0741
# Time for epoch 82 is 8.6013 sec
# Epoch 83, gen_loss: 1.5573, disc_loss: 1.0248
# Time for epoch 83 is 7.8266 sec
# Epoch 84, gen_loss: 1.6868, disc_loss: 0.9326
# Time for epoch 84 is 7.3734 sec
# Epoch 85, gen_loss: 1.6154, disc_loss: 0.9387
# Time for epoch 85 is 9.6492 sec
# Epoch 86, gen_loss: 1.6875, disc_loss: 0.9112
# Time for epoch 86 is 6.1354 sec
# Epoch 87, gen_loss: 1.5784, disc_loss: 0.8899
# Time for epoch 87 is 5.7426 sec
# Epoch 88, gen_loss: 1.3910, disc_loss: 1.0159
# Time for epoch 88 is 5.8467 sec
# Epoch 89, gen_loss: 1.6453, disc_loss: 0.8631
# Time for epoch 89 is 6.0122 sec
# Epoch 90, gen_loss: 1.5017, disc_loss: 0.9466
# Time for epoch 90 is 5.7874 sec
# Epoch 91, gen_loss: 1.5727, disc_loss: 1.0020
# Time for epoch 91 is 8.9819 sec
# Epoch 92, gen_loss: 1.7804, disc_loss: 0.8285
# Time for epoch 92 is 5.5240 sec
# Epoch 93, gen_loss: 1.5231, disc_loss: 1.0155
# Time for epoch 93 is 5.6463 sec
# Epoch 94, gen_loss: 1.5214, disc_loss: 1.0786
# Time for epoch 94 is 5.6512 sec
# Epoch 95, gen_loss: 1.5629, disc_loss: 0.9347
# Time for epoch 95 is 5.8374 sec
# Epoch 96, gen_loss: 1.7367, disc_loss: 0.8203
# Time for epoch 96 is 8.5110 sec
# Epoch 97, gen_loss: 1.6291, disc_loss: 0.8133
# Time for epoch 97 is 5.8271 sec
# Epoch 98, gen_loss: 1.5709, disc_loss: 0.9180
# Time for epoch 98 is 6.0386 sec
# Epoch 99, gen_loss: 1.7909, disc_loss: 0.7708
# Time for epoch 99 is 6.4806 sec
# Epoch 100, gen_loss: 1.7231, disc_loss: 0.8601
# Time for epoch 100 is 6.0731 sec
# Epoch 101, gen_loss: 2.0357, disc_loss: 0.6068
# Time for epoch 101 is 6.2050 sec
# Epoch 102, gen_loss: 1.6788, disc_loss: 0.8198
# Time for epoch 102 is 8.9539 sec
# Epoch 103, gen_loss: 1.7848, disc_loss: 0.7825
# Time for epoch 103 is 5.7779 sec
# Epoch 104, gen_loss: 1.8496, disc_loss: 0.8069
# Time for epoch 104 is 6.0387 sec
# Epoch 105, gen_loss: 1.6901, disc_loss: 0.8768
# Time for epoch 105 is 6.1622 sec
# Epoch 106, gen_loss: 1.7594, disc_loss: 0.8677
# Time for epoch 106 is 6.6162 sec
# Epoch 107, gen_loss: 1.7379, disc_loss: 0.8644
# Time for epoch 107 is 9.2408 sec
# Epoch 108, gen_loss: 1.6339, disc_loss: 1.0317
# Time for epoch 108 is 6.1035 sec
# Epoch 109, gen_loss: 1.7873, disc_loss: 0.9187
# Time for epoch 109 is 7.7006 sec
# Epoch 110, gen_loss: 1.7904, disc_loss: 0.9183
# Time for epoch 110 is 7.0775 sec
# Epoch 111, gen_loss: 1.9034, disc_loss: 0.7941
# Time for epoch 111 is 9.1085 sec
# Epoch 112, gen_loss: 1.4653, disc_loss: 1.0379
# Time for epoch 112 is 6.6097 sec
# Epoch 113, gen_loss: 1.6579, disc_loss: 0.8802
# Time for epoch 113 is 6.2334 sec
# Epoch 114, gen_loss: 1.6485, disc_loss: 1.0133
# Time for epoch 114 is 6.6363 sec
# Epoch 115, gen_loss: 1.7954, disc_loss: 0.9742
# Time for epoch 115 is 6.6764 sec
# Epoch 116, gen_loss: 1.6609, disc_loss: 1.0203
# Time for epoch 116 is 8.6466 sec
# Epoch 117, gen_loss: 1.7857, disc_loss: 0.8209
# Time for epoch 117 is 6.3821 sec
# Epoch 118, gen_loss: 1.7862, disc_loss: 0.7881
# Time for epoch 118 is 6.1144 sec
# 2025-11-19 00:00:55.611914: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 119, gen_loss: 1.5469, disc_loss: 0.9483
# Time for epoch 119 is 6.0726 sec
# Epoch 120, gen_loss: 1.4798, disc_loss: 1.0447
# Time for epoch 120 is 5.9917 sec
# Epoch 121, gen_loss: 1.6131, disc_loss: 0.9563
# Time for epoch 121 is 5.7368 sec
# Epoch 122, gen_loss: 1.4579, disc_loss: 1.0411
# Time for epoch 122 is 8.6366 sec
# Epoch 123, gen_loss: 1.4323, disc_loss: 1.0303
# Time for epoch 123 is 5.7960 sec
# Epoch 124, gen_loss: 1.3881, disc_loss: 1.0528
# Time for epoch 124 is 5.8756 sec
# Epoch 125, gen_loss: 1.5445, disc_loss: 0.9842
# Time for epoch 125 is 5.7908 sec
# Epoch 126, gen_loss: 1.4696, disc_loss: 1.0187
# Time for epoch 126 is 5.6987 sec
# Epoch 127, gen_loss: 1.4810, disc_loss: 0.9828
# Time for epoch 127 is 9.7869 sec
# Epoch 128, gen_loss: 1.4557, disc_loss: 1.0399
# Time for epoch 128 is 6.9226 sec
# Epoch 129, gen_loss: 1.2879, disc_loss: 1.1703
# Time for epoch 129 is 6.5490 sec
# Epoch 130, gen_loss: 1.5021, disc_loss: 1.0193
# Time for epoch 130 is 6.2184 sec
# Epoch 131, gen_loss: 1.4767, disc_loss: 1.0976
# Time for epoch 131 is 6.4778 sec
# Epoch 132, gen_loss: 1.5636, disc_loss: 1.0122
# Time for epoch 132 is 8.7862 sec
# Epoch 133, gen_loss: 1.4563, disc_loss: 1.1114
# Time for epoch 133 is 6.0690 sec
# Epoch 134, gen_loss: 1.5338, disc_loss: 1.0676
# Time for epoch 134 is 6.0813 sec
# Epoch 135, gen_loss: 1.4188, disc_loss: 1.0182
# Time for epoch 135 is 6.7991 sec
# Epoch 136, gen_loss: 1.4271, disc_loss: 1.0440
# Time for epoch 136 is 5.8888 sec
# Epoch 137, gen_loss: 1.4914, disc_loss: 1.1110
# Time for epoch 137 is 9.0204 sec
# Epoch 138, gen_loss: 1.5521, disc_loss: 1.1100
# Time for epoch 138 is 6.1729 sec
# Epoch 139, gen_loss: 1.5996, disc_loss: 0.9568
# Time for epoch 139 is 6.3105 sec
# Epoch 140, gen_loss: 1.7411, disc_loss: 0.8819
# Time for epoch 140 is 7.0876 sec
# Epoch 141, gen_loss: 1.9016, disc_loss: 0.6802
# Time for epoch 141 is 6.3592 sec
# Epoch 142, gen_loss: 1.7175, disc_loss: 0.7102
# Time for epoch 142 is 8.9100 sec
# Epoch 143, gen_loss: 1.8492, disc_loss: 0.6418
# Time for epoch 143 is 6.0191 sec
# Epoch 144, gen_loss: 1.7640, disc_loss: 0.7229
# Time for epoch 144 is 6.0028 sec
# Epoch 145, gen_loss: 1.8268, disc_loss: 0.7265
# Time for epoch 145 is 5.9900 sec
# Epoch 146, gen_loss: 1.7192, disc_loss: 0.8785
# Time for epoch 146 is 5.9504 sec
# Epoch 147, gen_loss: 1.6296, disc_loss: 0.8997
# Time for epoch 147 is 9.8297 sec
# Epoch 148, gen_loss: 1.8123, disc_loss: 0.8930
# Time for epoch 148 is 6.9196 sec
# Epoch 149, gen_loss: 1.7783, disc_loss: 0.9315
# Time for epoch 149 is 6.2325 sec
# Epoch 150, gen_loss: 1.7468, disc_loss: 0.9725
# Time for epoch 150 is 6.3843 sec
# Epoch 151, gen_loss: 1.9251, disc_loss: 0.8842
# Time for epoch 151 is 5.9259 sec
# Epoch 152, gen_loss: 1.7341, disc_loss: 0.9571
# Time for epoch 152 is 5.6707 sec
# Epoch 153, gen_loss: 1.7515, disc_loss: 0.9124
# Time for epoch 153 is 8.5107 sec
# Epoch 154, gen_loss: 1.8094, disc_loss: 0.9158
# Time for epoch 154 is 5.9824 sec
# Epoch 155, gen_loss: 1.7313, disc_loss: 0.9365
# Time for epoch 155 is 6.0526 sec
# Epoch 156, gen_loss: 1.8683, disc_loss: 0.8825
# Time for epoch 156 is 6.0146 sec
# Epoch 157, gen_loss: 1.6001, disc_loss: 0.9941
# Time for epoch 157 is 6.1653 sec
# Epoch 158, gen_loss: 1.6985, disc_loss: 0.9011
# Time for epoch 158 is 9.8198 sec
# Epoch 159, gen_loss: 1.5615, disc_loss: 1.0800
# Time for epoch 159 is 6.9855 sec
# Epoch 160, gen_loss: 1.5344, disc_loss: 1.1096
# Time for epoch 160 is 6.0180 sec
# Epoch 161, gen_loss: 1.7150, disc_loss: 0.9736
# Time for epoch 161 is 5.9511 sec
# Epoch 162, gen_loss: 1.5034, disc_loss: 1.1193
# Time for epoch 162 is 5.8542 sec
# Epoch 163, gen_loss: 1.6676, disc_loss: 0.9381
# Time for epoch 163 is 9.0025 sec
# Epoch 164, gen_loss: 1.4798, disc_loss: 1.1020
# Time for epoch 164 is 6.3073 sec
# Epoch 165, gen_loss: 1.4551, disc_loss: 1.1238
# Time for epoch 165 is 5.9985 sec
# Epoch 166, gen_loss: 1.4580, disc_loss: 1.1541
# Time for epoch 166 is 6.2561 sec
# Epoch 167, gen_loss: 1.6542, disc_loss: 0.9611
# Time for epoch 167 is 6.0311 sec
# Epoch 168, gen_loss: 1.6661, disc_loss: 0.8871
# Time for epoch 168 is 9.0585 sec
# Epoch 169, gen_loss: 1.6894, disc_loss: 0.9137
# Time for epoch 169 is 6.6732 sec
# Epoch 170, gen_loss: 1.8591, disc_loss: 0.8840
# Time for epoch 170 is 6.5405 sec
# Epoch 171, gen_loss: 1.9717, disc_loss: 0.8037
# Time for epoch 171 is 5.8844 sec
# Epoch 172, gen_loss: 1.9335, disc_loss: 0.6977
# Time for epoch 172 is 7.0286 sec
# Epoch 173, gen_loss: 1.8032, disc_loss: 0.8481
# Time for epoch 173 is 9.1220 sec
# Epoch 174, gen_loss: 1.9094, disc_loss: 0.8312
# Time for epoch 174 is 6.6787 sec
# Epoch 175, gen_loss: 1.8514, disc_loss: 0.8421
# Time for epoch 175 is 5.6219 sec
# Epoch 176, gen_loss: 1.8481, disc_loss: 0.8845
# Time for epoch 176 is 5.8115 sec
# Epoch 177, gen_loss: 1.8616, disc_loss: 0.8574
# Time for epoch 177 is 6.0597 sec
# Epoch 178, gen_loss: 1.6920, disc_loss: 0.9434
# Time for epoch 178 is 9.5621 sec
# Epoch 179, gen_loss: 1.6374, disc_loss: 0.9668
# Time for epoch 179 is 6.4401 sec
# Epoch 180, gen_loss: 1.5528, disc_loss: 1.1412
# Time for epoch 180 is 5.9397 sec
# Epoch 181, gen_loss: 1.7137, disc_loss: 0.9752
# Time for epoch 181 is 6.9674 sec
# Epoch 182, gen_loss: 1.5630, disc_loss: 1.0270
# Time for epoch 182 is 6.1463 sec
# Epoch 183, gen_loss: 1.6980, disc_loss: 0.9771
# Time for epoch 183 is 9.1417 sec
# Epoch 184, gen_loss: 1.7890, disc_loss: 0.8818
# Time for epoch 184 is 6.8450 sec
# Epoch 185, gen_loss: 1.6368, disc_loss: 0.9739
# Time for epoch 185 is 6.2796 sec
# Epoch 186, gen_loss: 1.5506, disc_loss: 1.0596
# Time for epoch 186 is 6.1547 sec
# Epoch 187, gen_loss: 1.5555, disc_loss: 1.0022
# Time for epoch 187 is 6.3704 sec
# Epoch 188, gen_loss: 1.4575, disc_loss: 1.0733
# Time for epoch 188 is 8.7057 sec
# Epoch 189, gen_loss: 1.5836, disc_loss: 1.0179
# Time for epoch 189 is 6.1169 sec
# Epoch 190, gen_loss: 1.5597, disc_loss: 1.0822
# Time for epoch 190 is 6.1976 sec
# Epoch 191, gen_loss: 1.4768, disc_loss: 1.0737
# Time for epoch 191 is 6.9403 sec
# Epoch 192, gen_loss: 1.4487, disc_loss: 1.1445
# Time for epoch 192 is 6.3373 sec
# Epoch 193, gen_loss: 1.6342, disc_loss: 1.1359
# Time for epoch 193 is 9.3386 sec
# Epoch 194, gen_loss: 1.4792, disc_loss: 1.1008
# Time for epoch 194 is 6.3660 sec
# Epoch 195, gen_loss: 1.4910, disc_loss: 1.1151
# Time for epoch 195 is 6.7213 sec
# 2025-11-19 00:09:53.133746: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:24: Filling up shuffle buffer (this may take a while): 5808 of 7370
# 2025-11-19 00:09:54.716111: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:483] Shuffle buffer filled.
# Epoch 196, gen_loss: 1.5020, disc_loss: 1.1874
# Time for epoch 196 is 12.8369 sec
# Epoch 197, gen_loss: 1.6647, disc_loss: 1.0103
# Time for epoch 197 is 9.3718 sec
# Epoch 198, gen_loss: 1.5587, disc_loss: 1.0023
# Time for epoch 198 is 6.1760 sec
# Epoch 199, gen_loss: 1.5826, disc_loss: 1.0789
# Time for epoch 199 is 10.2270 sec
# Epoch 200, gen_loss: 1.4385, disc_loss: 1.1876
# Time for epoch 200 is 6.4763 sec
# Epoch 201, gen_loss: 1.5747, disc_loss: 1.0684
# Time for epoch 201 is 10.0416 sec
# Epoch 202, gen_loss: 1.4573, disc_loss: 1.1758
# Time for epoch 202 is 6.0276 sec
# Epoch 203, gen_loss: 1.5890, disc_loss: 1.0697
# Time for epoch 203 is 6.3927 sec
# Epoch 204, gen_loss: 1.4824, disc_loss: 1.0583
# Time for epoch 204 is 7.2034 sec
# Epoch 205, gen_loss: 1.5384, disc_loss: 1.0545
# Time for epoch 205 is 6.4880 sec
# Epoch 206, gen_loss: 1.4727, disc_loss: 1.0805
# Time for epoch 206 is 10.2695 sec
# Epoch 207, gen_loss: 1.4575, disc_loss: 1.1106
# Time for epoch 207 is 6.1055 sec
# Epoch 208, gen_loss: 1.4821, disc_loss: 1.0366
# Time for epoch 208 is 6.8301 sec
# Epoch 209, gen_loss: 1.4658, disc_loss: 1.1293
# Time for epoch 209 is 6.1567 sec
# Epoch 210, gen_loss: 1.4034, disc_loss: 1.2617
# Time for epoch 210 is 6.6566 sec
# Epoch 211, gen_loss: 1.4242, disc_loss: 1.1990
# Time for epoch 211 is 8.6711 sec
# Epoch 212, gen_loss: 1.6224, disc_loss: 1.0601
# Time for epoch 212 is 5.6410 sec
# Epoch 213, gen_loss: 1.4819, disc_loss: 1.1417
# Time for epoch 213 is 6.3474 sec
# Epoch 214, gen_loss: 1.5560, disc_loss: 1.0127
# Time for epoch 214 is 6.7408 sec
# Epoch 215, gen_loss: 1.4590, disc_loss: 1.1573
# Time for epoch 215 is 6.3491 sec
# Epoch 216, gen_loss: 1.6985, disc_loss: 0.9853
# Time for epoch 216 is 9.7381 sec
# Epoch 217, gen_loss: 1.5156, disc_loss: 1.0439
# Time for epoch 217 is 5.9152 sec
# Epoch 218, gen_loss: 1.6597, disc_loss: 0.9148
# Time for epoch 218 is 6.2038 sec
# Epoch 219, gen_loss: 1.4528, disc_loss: 1.1444
# Time for epoch 219 is 6.2338 sec
# Epoch 220, gen_loss: 1.3472, disc_loss: 1.2411
# Time for epoch 220 is 6.9569 sec
# Epoch 221, gen_loss: 1.5416, disc_loss: 1.1362
# Time for epoch 221 is 9.0741 sec
# Epoch 222, gen_loss: 1.6757, disc_loss: 0.9771
# Time for epoch 222 is 6.6339 sec
# Epoch 223, gen_loss: 1.5047, disc_loss: 1.0569
# Time for epoch 223 is 6.6067 sec
# Epoch 224, gen_loss: 1.4159, disc_loss: 1.1479
# Time for epoch 224 is 6.8178 sec
# Epoch 225, gen_loss: 1.3623, disc_loss: 1.1977
# Time for epoch 225 is 5.9038 sec
# Epoch 226, gen_loss: 1.4785, disc_loss: 1.1601
# Time for epoch 226 is 8.7063 sec
# Epoch 227, gen_loss: 1.4569, disc_loss: 1.1688
# Time for epoch 227 is 6.2089 sec
# Epoch 228, gen_loss: 1.6112, disc_loss: 1.1071
# Time for epoch 228 is 5.9401 sec
# Epoch 229, gen_loss: 1.5267, disc_loss: 1.1047
# Time for epoch 229 is 6.3146 sec
# Epoch 230, gen_loss: 1.5935, disc_loss: 1.0979
# Time for epoch 230 is 6.4839 sec
# Epoch 231, gen_loss: 1.7101, disc_loss: 0.9331
# Time for epoch 231 is 9.1822 sec
# Epoch 232, gen_loss: 1.5532, disc_loss: 1.0764
# Time for epoch 232 is 5.8361 sec
# Epoch 233, gen_loss: 1.6127, disc_loss: 0.9909
# Time for epoch 233 is 5.9749 sec
# Epoch 234, gen_loss: 1.4523, disc_loss: 1.1531
# Time for epoch 234 is 5.6663 sec
# Epoch 235, gen_loss: 1.6169, disc_loss: 1.0250
# Time for epoch 235 is 6.4635 sec
# Epoch 236, gen_loss: 1.6040, disc_loss: 1.0140
# Time for epoch 236 is 6.6699 sec
# Epoch 237, gen_loss: 1.5169, disc_loss: 1.0833
# Time for epoch 237 is 9.5253 sec
# Epoch 238, gen_loss: 1.5042, disc_loss: 1.0798
# Time for epoch 238 is 6.7892 sec
# Epoch 239, gen_loss: 1.6516, disc_loss: 1.0203
# Time for epoch 239 is 5.6583 sec
# Epoch 240, gen_loss: 1.4272, disc_loss: 1.1828
# Time for epoch 240 is 5.5936 sec
# Epoch 241, gen_loss: 1.6429, disc_loss: 1.0404
# Time for epoch 241 is 5.8659 sec
# Epoch 242, gen_loss: 1.6746, disc_loss: 1.0479
# Time for epoch 242 is 8.9890 sec
# Epoch 243, gen_loss: 1.5525, disc_loss: 1.0626
# Time for epoch 243 is 6.6909 sec
# Epoch 244, gen_loss: 1.5709, disc_loss: 0.9864
# Time for epoch 244 is 6.1994 sec
# Epoch 245, gen_loss: 1.6731, disc_loss: 0.9526
# Time for epoch 245 is 5.9959 sec
# Epoch 246, gen_loss: 1.4825, disc_loss: 1.2011
# Time for epoch 246 is 5.9472 sec
# 2025-11-19 00:15:47.540746: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 247, gen_loss: 1.7208, disc_loss: 0.9575
# Time for epoch 247 is 8.8089 sec
# Epoch 248, gen_loss: 1.5742, disc_loss: 0.9886
# Time for epoch 248 is 6.2782 sec
# Epoch 249, gen_loss: 1.6643, disc_loss: 0.8866
# Time for epoch 249 is 7.0054 sec
# Epoch 250, gen_loss: 1.4031, disc_loss: 1.1704
# Time for epoch 250 is 6.1672 sec
# Epoch 251, gen_loss: 1.5151, disc_loss: 1.0678
# Time for epoch 251 is 6.5822 sec
# Epoch 252, gen_loss: 1.5337, disc_loss: 1.0863
# Time for epoch 252 is 9.1965 sec
# Epoch 253, gen_loss: 1.5235, disc_loss: 1.0815
# Time for epoch 253 is 6.2257 sec
# Epoch 254, gen_loss: 1.5091, disc_loss: 1.1236
# Time for epoch 254 is 6.2603 sec
# Epoch 255, gen_loss: 1.6282, disc_loss: 0.9375
# Time for epoch 255 is 5.8817 sec
# Epoch 256, gen_loss: 1.4227, disc_loss: 1.1569
# Time for epoch 256 is 6.3715 sec
# Epoch 257, gen_loss: 1.5686, disc_loss: 0.9964
# Time for epoch 257 is 8.8179 sec
# Epoch 258, gen_loss: 1.5061, disc_loss: 1.1102
# Time for epoch 258 is 6.3685 sec
# Epoch 259, gen_loss: 1.6218, disc_loss: 0.9563
# Time for epoch 259 is 7.3426 sec
# Epoch 260, gen_loss: 1.4280, disc_loss: 1.2050
# Time for epoch 260 is 6.4251 sec
# Epoch 261, gen_loss: 1.6618, disc_loss: 1.0151
# Time for epoch 261 is 6.5472 sec
# Epoch 262, gen_loss: 1.6727, disc_loss: 0.9392
# Time for epoch 262 is 9.0505 sec
# Epoch 263, gen_loss: 1.4661, disc_loss: 1.1346
# Time for epoch 263 is 6.8072 sec
# Epoch 264, gen_loss: 1.6589, disc_loss: 0.9835
# Time for epoch 264 is 6.6610 sec
# Epoch 265, gen_loss: 1.4859, disc_loss: 1.1251
# Time for epoch 265 is 6.4026 sec
# Epoch 266, gen_loss: 1.5141, disc_loss: 1.0936
# Time for epoch 266 is 5.7335 sec
# Epoch 267, gen_loss: 1.5388, disc_loss: 1.0319
# Time for epoch 267 is 8.4842 sec
# Epoch 268, gen_loss: 1.4619, disc_loss: 1.1288
# Time for epoch 268 is 6.3614 sec
# Epoch 269, gen_loss: 1.5499, disc_loss: 1.0198
# Time for epoch 269 is 5.7605 sec
# Epoch 270, gen_loss: 1.3562, disc_loss: 1.2971
# Time for epoch 270 is 5.7890 sec
# Epoch 271, gen_loss: 1.6421, disc_loss: 0.9833
# Time for epoch 271 is 7.2599 sec
# Epoch 272, gen_loss: 1.5305, disc_loss: 1.0975
# Time for epoch 272 is 10.1738 sec
# Epoch 273, gen_loss: 1.5513, disc_loss: 1.1285
# Time for epoch 273 is 6.5627 sec
# Epoch 274, gen_loss: 1.6383, disc_loss: 1.0416
# Time for epoch 274 is 8.1741 sec
# Epoch 275, gen_loss: 1.5812, disc_loss: 1.1741
# Time for epoch 275 is 6.5885 sec
# Epoch 276, gen_loss: 1.6725, disc_loss: 1.0128
# Time for epoch 276 is 8.5497 sec
# Epoch 277, gen_loss: 1.6350, disc_loss: 1.0130
# Time for epoch 277 is 9.0125 sec
# Epoch 278, gen_loss: 1.6609, disc_loss: 0.9943
# Time for epoch 278 is 6.6681 sec
# Epoch 279, gen_loss: 1.5011, disc_loss: 1.1407
# Time for epoch 279 is 6.4467 sec
# Epoch 280, gen_loss: 1.6602, disc_loss: 0.9914
# Time for epoch 280 is 6.5163 sec
# Epoch 281, gen_loss: 1.7176, disc_loss: 1.0169
# Time for epoch 281 is 9.6263 sec
# Epoch 282, gen_loss: 1.6313, disc_loss: 1.0090
# Time for epoch 282 is 6.0235 sec
# Epoch 283, gen_loss: 1.9127, disc_loss: 0.8922
# Time for epoch 283 is 6.2941 sec
# Epoch 284, gen_loss: 1.7442, disc_loss: 1.0873
# Time for epoch 284 is 6.1743 sec
# Epoch 285, gen_loss: 1.7448, disc_loss: 0.9935
# Time for epoch 285 is 8.6509 sec
# Epoch 286, gen_loss: 1.7171, disc_loss: 0.9302
# Time for epoch 286 is 9.3050 sec
# Epoch 287, gen_loss: 1.7734, disc_loss: 0.9148
# Time for epoch 287 is 6.7392 sec
# Epoch 288, gen_loss: 1.7864, disc_loss: 0.9083
# Time for epoch 288 is 6.3202 sec
# Epoch 289, gen_loss: 1.8461, disc_loss: 0.9460
# Time for epoch 289 is 6.3902 sec
# Epoch 290, gen_loss: 2.0932, disc_loss: 0.7973
# Time for epoch 290 is 6.1406 sec
# Epoch 291, gen_loss: 1.8658, disc_loss: 0.9135
# Time for epoch 291 is 9.2839 sec
# Epoch 292, gen_loss: 1.8960, disc_loss: 0.8485
# Time for epoch 292 is 6.5063 sec
# Epoch 293, gen_loss: 1.9586, disc_loss: 0.7835
# Time for epoch 293 is 6.2174 sec
# Epoch 294, gen_loss: 1.7157, disc_loss: 0.9125
# Time for epoch 294 is 5.9781 sec
# Epoch 295, gen_loss: 1.8321, disc_loss: 0.8759
# Time for epoch 295 is 6.0314 sec
# Epoch 296, gen_loss: 1.7821, disc_loss: 0.9224
# Time for epoch 296 is 5.9169 sec
# Epoch 297, gen_loss: 1.9722, disc_loss: 0.8790
# Time for epoch 297 is 8.8818 sec
# Epoch 298, gen_loss: 1.7985, disc_loss: 1.0184
# Time for epoch 298 is 5.8374 sec
# Epoch 299, gen_loss: 2.0732, disc_loss: 0.8183
# Time for epoch 299 is 6.0074 sec
# Epoch 300, gen_loss: 1.8181, disc_loss: 0.9201
# Time for epoch 300 is 6.0372 sec
# Epoch 301, gen_loss: 1.8246, disc_loss: 0.9060
# Time for epoch 301 is 6.3352 sec
# Epoch 302, gen_loss: 1.6641, disc_loss: 1.0234
# Time for epoch 302 is 9.3706 sec
# Epoch 303, gen_loss: 1.7836, disc_loss: 1.0048
# Time for epoch 303 is 6.3891 sec
# Epoch 304, gen_loss: 1.9252, disc_loss: 0.9033
# Time for epoch 304 is 5.7707 sec
# Epoch 305, gen_loss: 1.9774, disc_loss: 0.9108
# Time for epoch 305 is 5.7829 sec
# Epoch 306, gen_loss: 1.9131, disc_loss: 0.8480
# Time for epoch 306 is 6.3234 sec
# Epoch 307, gen_loss: 2.0133, disc_loss: 0.7126
# Time for epoch 307 is 9.1795 sec
# Epoch 308, gen_loss: 1.9204, disc_loss: 0.8053
# Time for epoch 308 is 5.7338 sec
# Epoch 309, gen_loss: 1.9192, disc_loss: 0.8658
# Time for epoch 309 is 5.8573 sec
# Epoch 310, gen_loss: 1.8942, disc_loss: 0.9085
# Time for epoch 310 is 7.3365 sec
# Epoch 311, gen_loss: 2.0033, disc_loss: 0.8319
# Time for epoch 311 is 6.8993 sec
# Epoch 312, gen_loss: 1.9725, disc_loss: 0.8628
# Time for epoch 312 is 10.0863 sec
# Epoch 313, gen_loss: 1.8368, disc_loss: 0.9570
# Time for epoch 313 is 6.2638 sec
# Epoch 314, gen_loss: 1.8897, disc_loss: 0.9114
# Time for epoch 314 is 5.7306 sec
# Epoch 315, gen_loss: 1.7321, disc_loss: 0.9493
# Time for epoch 315 is 5.8395 sec
# Epoch 316, gen_loss: 1.6457, disc_loss: 1.1260
# Time for epoch 316 is 5.4104 sec
# Epoch 317, gen_loss: 1.7435, disc_loss: 1.0644
# Time for epoch 317 is 8.8909 sec
# Epoch 318, gen_loss: 1.7807, disc_loss: 1.0145
# Time for epoch 318 is 5.9002 sec
# Epoch 319, gen_loss: 1.7093, disc_loss: 1.0316
# Time for epoch 319 is 5.9371 sec
# Epoch 320, gen_loss: 2.0304, disc_loss: 0.8966
# Time for epoch 320 is 6.8071 sec
# Epoch 321, gen_loss: 1.6768, disc_loss: 1.0879
# Time for epoch 321 is 6.2575 sec
# Epoch 322, gen_loss: 1.7297, disc_loss: 1.0488
# Time for epoch 322 is 5.5408 sec
# Epoch 323, gen_loss: 1.7298, disc_loss: 1.0640
# Time for epoch 323 is 9.2674 sec
# Epoch 324, gen_loss: 1.9326, disc_loss: 0.8582
# Time for epoch 324 is 5.9126 sec
# Epoch 325, gen_loss: 1.6812, disc_loss: 1.0704
# Time for epoch 325 is 5.8073 sec
# Epoch 326, gen_loss: 2.0450, disc_loss: 0.8103
# Time for epoch 326 is 5.5696 sec
# Epoch 327, gen_loss: 1.6669, disc_loss: 1.1221
# Time for epoch 327 is 5.5491 sec
# Epoch 328, gen_loss: 1.7956, disc_loss: 0.9571
# Time for epoch 328 is 8.9965 sec
# Epoch 329, gen_loss: 1.7460, disc_loss: 0.9597
# Time for epoch 329 is 6.5286 sec
# Epoch 330, gen_loss: 1.8693, disc_loss: 0.9104
# Time for epoch 330 is 5.9755 sec
# Epoch 331, gen_loss: 1.7178, disc_loss: 1.0445
# Time for epoch 331 is 5.6669 sec
# Epoch 332, gen_loss: 1.7719, disc_loss: 1.0671
# Time for epoch 332 is 6.7969 sec
# Epoch 333, gen_loss: 1.8003, disc_loss: 0.9674
# Time for epoch 333 is 9.9720 sec
# Epoch 334, gen_loss: 1.7210, disc_loss: 0.9695
# Time for epoch 334 is 6.1226 sec
# Epoch 335, gen_loss: 1.6696, disc_loss: 1.0658
# Time for epoch 335 is 6.9663 sec
# Epoch 336, gen_loss: 1.8368, disc_loss: 1.0024
# Time for epoch 336 is 5.5647 sec
# Epoch 337, gen_loss: 1.8283, disc_loss: 1.0422
# Time for epoch 337 is 6.0509 sec
# Epoch 338, gen_loss: 1.7640, disc_loss: 1.0573
# Time for epoch 338 is 8.8373 sec
# Epoch 339, gen_loss: 1.7734, disc_loss: 0.9704
# Time for epoch 339 is 5.7377 sec
# Epoch 340, gen_loss: 1.7540, disc_loss: 1.0716
# Time for epoch 340 is 5.7918 sec
# Epoch 341, gen_loss: 1.9636, disc_loss: 0.9295
# Time for epoch 341 is 5.6996 sec
# Epoch 342, gen_loss: 1.6449, disc_loss: 1.1460
# Time for epoch 342 is 6.1334 sec
# Epoch 343, gen_loss: 1.8812, disc_loss: 0.9496
# Time for epoch 343 is 6.1963 sec
# Epoch 344, gen_loss: 2.0150, disc_loss: 0.8591
# Time for epoch 344 is 10.6778 sec
# Epoch 345, gen_loss: 1.9303, disc_loss: 0.9400
# Time for epoch 345 is 6.6169 sec
# Epoch 346, gen_loss: 1.9081, disc_loss: 1.0088
# Time for epoch 346 is 5.8911 sec
# Epoch 347, gen_loss: 2.1062, disc_loss: 0.8529
# Time for epoch 347 is 6.1388 sec
# Epoch 348, gen_loss: 1.8530, disc_loss: 0.9848
# Time for epoch 348 is 6.7309 sec
# Epoch 349, gen_loss: 1.7524, disc_loss: 1.0137
# Time for epoch 349 is 9.8997 sec
# Epoch 350, gen_loss: 2.1180, disc_loss: 0.8118
# Time for epoch 350 is 6.8107 sec
# Epoch 351, gen_loss: 1.9796, disc_loss: 0.9468
# Time for epoch 351 is 5.6446 sec
# Epoch 352, gen_loss: 1.9893, disc_loss: 0.9857
# Time for epoch 352 is 6.1395 sec
# Epoch 353, gen_loss: 2.0870, disc_loss: 0.8629
# Time for epoch 353 is 5.7513 sec
# Epoch 354, gen_loss: 2.0037, disc_loss: 0.8764
# Time for epoch 354 is 9.3464 sec
# Epoch 355, gen_loss: 1.7701, disc_loss: 1.0342
# Time for epoch 355 is 6.1112 sec
# Epoch 356, gen_loss: 1.9597, disc_loss: 0.8940
# Time for epoch 356 is 5.6866 sec
# Epoch 357, gen_loss: 1.9113, disc_loss: 0.9472
# Time for epoch 357 is 5.6778 sec
# Epoch 358, gen_loss: 1.7124, disc_loss: 1.0704
# Time for epoch 358 is 5.5764 sec
# Epoch 359, gen_loss: 1.7920, disc_loss: 1.0377
# Time for epoch 359 is 8.8876 sec
# Epoch 360, gen_loss: 1.8152, disc_loss: 1.0749
# Time for epoch 360 is 5.8513 sec
# Epoch 361, gen_loss: 2.0299, disc_loss: 0.9467
# Time for epoch 361 is 5.6193 sec
# Epoch 362, gen_loss: 1.7940, disc_loss: 1.0500
# Time for epoch 362 is 5.8748 sec
# Epoch 363, gen_loss: 1.9479, disc_loss: 0.9718
# Time for epoch 363 is 6.1846 sec
# Epoch 364, gen_loss: 1.8762, disc_loss: 0.9592
# Time for epoch 364 is 6.9252 sec
# Epoch 365, gen_loss: 1.8687, disc_loss: 0.9741
# Time for epoch 365 is 13.2675 sec
# Epoch 366, gen_loss: 1.9121, disc_loss: 0.9448
# Time for epoch 366 is 6.6036 sec
# Epoch 367, gen_loss: 2.0065, disc_loss: 0.8880
# Time for epoch 367 is 6.5348 sec
# Epoch 368, gen_loss: 1.7191, disc_loss: 1.0435
# Time for epoch 368 is 5.8967 sec
# Epoch 369, gen_loss: 1.9324, disc_loss: 0.9509
# Time for epoch 369 is 9.0330 sec
# Epoch 370, gen_loss: 1.9334, disc_loss: 0.9184
# Time for epoch 370 is 8.0397 sec
# Epoch 371, gen_loss: 1.8325, disc_loss: 0.9680
# Time for epoch 371 is 6.7842 sec
# Epoch 372, gen_loss: 1.9423, disc_loss: 0.8897
# Time for epoch 372 is 6.9049 sec
# Epoch 373, gen_loss: 1.9145, disc_loss: 0.9186
# Time for epoch 373 is 5.8776 sec
# Epoch 374, gen_loss: 1.7816, disc_loss: 0.9564
# Time for epoch 374 is 8.4584 sec
# Epoch 375, gen_loss: 2.0223, disc_loss: 0.9114
# Time for epoch 375 is 5.8669 sec
# Epoch 376, gen_loss: 1.8528, disc_loss: 1.0442
# Time for epoch 376 is 5.8922 sec
# Epoch 377, gen_loss: 2.1221, disc_loss: 0.7902
# Time for epoch 377 is 5.7824 sec
# Epoch 378, gen_loss: 1.8418, disc_loss: 0.9980
# Time for epoch 378 is 6.1078 sec
# Epoch 379, gen_loss: 2.0272, disc_loss: 0.8725
# Time for epoch 379 is 9.9032 sec
# Epoch 380, gen_loss: 2.1621, disc_loss: 0.7504
# Time for epoch 380 is 6.1623 sec
# Epoch 381, gen_loss: 1.9057, disc_loss: 0.8571
# Time for epoch 381 is 5.8676 sec
# Epoch 382, gen_loss: 2.0575, disc_loss: 0.8215
# Time for epoch 382 is 5.9048 sec
# Epoch 383, gen_loss: 2.0801, disc_loss: 0.8809
# Time for epoch 383 is 6.1960 sec
# Epoch 384, gen_loss: 2.0538, disc_loss: 0.8595
# Time for epoch 384 is 5.7470 sec
# Epoch 385, gen_loss: 2.2590, disc_loss: 0.6956
# Time for epoch 385 is 9.4393 sec
# Epoch 386, gen_loss: 2.0170, disc_loss: 0.8290
# Time for epoch 386 is 6.8406 sec
# Epoch 387, gen_loss: 2.0061, disc_loss: 0.8696
# Time for epoch 387 is 6.1025 sec
# Epoch 388, gen_loss: 2.2561, disc_loss: 0.7942
# Time for epoch 388 is 6.0771 sec
# Epoch 389, gen_loss: 2.1757, disc_loss: 0.7559
# Time for epoch 389 is 9.5018 sec
# Epoch 390, gen_loss: 2.0837, disc_loss: 0.8076
# Time for epoch 390 is 6.3335 sec
# Epoch 391, gen_loss: 2.1675, disc_loss: 0.7330
# Time for epoch 391 is 6.6436 sec
# Epoch 392, gen_loss: 2.1610, disc_loss: 0.7572
# Time for epoch 392 is 6.6062 sec
# Epoch 393, gen_loss: 2.1080, disc_loss: 0.7968
# Time for epoch 393 is 7.7937 sec
# Epoch 394, gen_loss: 2.1882, disc_loss: 0.7283
# Time for epoch 394 is 9.6170 sec
# Epoch 395, gen_loss: 2.2640, disc_loss: 0.7360
# Time for epoch 395 is 6.4131 sec
# Epoch 396, gen_loss: 2.0059, disc_loss: 0.8443
# Time for epoch 396 is 6.0644 sec
# Epoch 397, gen_loss: 2.1151, disc_loss: 0.7828
# Time for epoch 397 is 5.9898 sec
# Epoch 398, gen_loss: 2.0572, disc_loss: 0.8260
# Time for epoch 398 is 5.7461 sec
# Epoch 399, gen_loss: 2.0588, disc_loss: 0.7994
# Time for epoch 399 is 8.9603 sec
# Epoch 400, gen_loss: 2.0925, disc_loss: 0.7782
# Time for epoch 400 is 5.7516 sec
# Epoch 401, gen_loss: 2.0437, disc_loss: 0.8180
# Time for epoch 401 is 7.1187 sec
# Epoch 402, gen_loss: 1.9963, disc_loss: 0.8249
# Time for epoch 402 is 6.4201 sec
# Epoch 403, gen_loss: 1.9871, disc_loss: 0.8218
# Time for epoch 403 is 5.7843 sec
# Epoch 404, gen_loss: 1.9978, disc_loss: 0.8513
# Time for epoch 404 is 8.7353 sec
# Epoch 405, gen_loss: 2.1466, disc_loss: 0.7338
# Time for epoch 405 is 6.1325 sec
# Epoch 406, gen_loss: 1.9819, disc_loss: 0.8632
# Time for epoch 406 is 6.3351 sec
# Epoch 407, gen_loss: 2.0660, disc_loss: 0.7785
# Time for epoch 407 is 7.2225 sec
# Epoch 408, gen_loss: 1.9145, disc_loss: 0.9161
# Time for epoch 408 is 6.9540 sec
# Epoch 409, gen_loss: 2.1156, disc_loss: 0.7384
# Time for epoch 409 is 9.1969 sec
# Epoch 410, gen_loss: 1.9855, disc_loss: 0.8605
# Time for epoch 410 is 5.8874 sec
# Epoch 411, gen_loss: 1.9704, disc_loss: 0.8858
# Time for epoch 411 is 5.8893 sec
# Epoch 412, gen_loss: 2.0620, disc_loss: 0.7834
# Time for epoch 412 is 6.7275 sec
# Epoch 413, gen_loss: 2.1194, disc_loss: 0.7935
# Time for epoch 413 is 6.5910 sec
# Epoch 414, gen_loss: 2.1413, disc_loss: 0.8395
# Time for epoch 414 is 10.5029 sec
# Epoch 415, gen_loss: 2.0497, disc_loss: 0.7911
# Time for epoch 415 is 8.4470 sec
# Epoch 416, gen_loss: 2.1250, disc_loss: 0.7400
# Time for epoch 416 is 6.5183 sec
# Epoch 417, gen_loss: 2.1631, disc_loss: 0.7865
# Time for epoch 417 is 6.0437 sec
# Epoch 418, gen_loss: 2.1696, disc_loss: 0.8133
# Time for epoch 418 is 6.8748 sec
# Epoch 419, gen_loss: 2.0495, disc_loss: 0.8666
# Time for epoch 419 is 10.3421 sec
# Epoch 420, gen_loss: 2.1388, disc_loss: 0.8115
# Time for epoch 420 is 6.5033 sec
# Epoch 421, gen_loss: 2.1553, disc_loss: 0.7798
# Time for epoch 421 is 7.0496 sec
# Epoch 422, gen_loss: 2.0985, disc_loss: 0.7882
# Time for epoch 422 is 6.6677 sec
# Epoch 423, gen_loss: 2.2045, disc_loss: 0.7251
# Time for epoch 423 is 10.1268 sec
# Epoch 424, gen_loss: 2.0486, disc_loss: 0.8642
# Time for epoch 424 is 6.4244 sec
# Epoch 425, gen_loss: 2.1230, disc_loss: 0.7929
# Time for epoch 425 is 6.9464 sec
# Epoch 426, gen_loss: 2.0573, disc_loss: 0.8206
# Time for epoch 426 is 5.8148 sec
# Epoch 427, gen_loss: 1.9515, disc_loss: 0.8550
# Time for epoch 427 is 5.9063 sec
# Epoch 428, gen_loss: 1.9786, disc_loss: 0.8417
# Time for epoch 428 is 13.3635 sec
# Epoch 429, gen_loss: 2.1243, disc_loss: 0.8265
# Time for epoch 429 is 5.6687 sec
# Epoch 430, gen_loss: 1.9989, disc_loss: 0.8615
# Time for epoch 430 is 5.5046 sec
# Epoch 431, gen_loss: 2.0737, disc_loss: 0.8776
# Time for epoch 431 is 5.7505 sec
# Epoch 432, gen_loss: 2.1271, disc_loss: 0.7800
# Time for epoch 432 is 5.5487 sec
# Epoch 433, gen_loss: 2.0805, disc_loss: 0.7987
# Time for epoch 433 is 5.4036 sec
# Epoch 434, gen_loss: 1.9774, disc_loss: 0.8746
# Time for epoch 434 is 9.4062 sec
# Epoch 435, gen_loss: 2.1302, disc_loss: 0.7978
# Time for epoch 435 is 5.6452 sec
# Epoch 436, gen_loss: 2.0694, disc_loss: 0.7934
# Time for epoch 436 is 5.7306 sec
# Epoch 437, gen_loss: 2.1401, disc_loss: 0.7980
# Time for epoch 437 is 5.9333 sec
# Epoch 438, gen_loss: 2.0935, disc_loss: 0.8273
# Time for epoch 438 is 6.8058 sec
# Epoch 439, gen_loss: 2.2567, disc_loss: 0.6922
# Time for epoch 439 is 9.1132 sec
# Epoch 440, gen_loss: 2.1183, disc_loss: 0.8220
# Time for epoch 440 is 6.2100 sec
# Epoch 441, gen_loss: 2.1452, disc_loss: 0.8091
# Time for epoch 441 is 5.6330 sec
# Epoch 442, gen_loss: 2.3295, disc_loss: 0.7003
# Time for epoch 442 is 5.6760 sec
# Epoch 443, gen_loss: 2.1169, disc_loss: 0.7834
# Time for epoch 443 is 5.7483 sec
# Epoch 444, gen_loss: 2.1386, disc_loss: 0.7907
# Time for epoch 444 is 8.9988 sec
# Epoch 445, gen_loss: 2.2632, disc_loss: 0.7543
# Time for epoch 445 is 5.8686 sec
# Epoch 446, gen_loss: 2.1865, disc_loss: 0.8107
# Time for epoch 446 is 7.2038 sec
# Epoch 447, gen_loss: 2.3658, disc_loss: 0.7365
# Time for epoch 447 is 6.2430 sec
# Epoch 448, gen_loss: 2.1172, disc_loss: 0.8674
# Time for epoch 448 is 6.1654 sec
# Epoch 449, gen_loss: 2.2293, disc_loss: 0.7805
# Time for epoch 449 is 9.0558 sec
# Epoch 450, gen_loss: 2.2457, disc_loss: 0.7419
# Time for epoch 450 is 5.8196 sec
# Epoch 451, gen_loss: 2.2513, disc_loss: 0.7429
# Time for epoch 451 is 7.3473 sec
# Epoch 452, gen_loss: 2.2035, disc_loss: 0.7981
# Time for epoch 452 is 7.6283 sec
# Epoch 453, gen_loss: 2.3736, disc_loss: 0.7198
# Time for epoch 453 is 7.1079 sec
# Epoch 454, gen_loss: 2.1196, disc_loss: 0.8757
# Time for epoch 454 is 9.7002 sec
# Epoch 455, gen_loss: 2.3152, disc_loss: 0.7629
# Time for epoch 455 is 6.4351 sec
# Epoch 456, gen_loss: 2.2636, disc_loss: 0.7813
# Time for epoch 456 is 10.2282 sec
# Epoch 457, gen_loss: 2.3299, disc_loss: 0.7427
# Time for epoch 457 is 6.4375 sec
# Epoch 458, gen_loss: 2.3871, disc_loss: 0.7391
# Time for epoch 458 is 10.1352 sec
# Epoch 459, gen_loss: 2.1917, disc_loss: 0.8114
# Time for epoch 459 is 6.1937 sec
# Epoch 460, gen_loss: 2.2888, disc_loss: 0.7470
# Time for epoch 460 is 7.1257 sec
# Epoch 461, gen_loss: 2.2888, disc_loss: 0.7946
# Time for epoch 461 is 6.2948 sec
# Epoch 462, gen_loss: 2.3801, disc_loss: 0.7375
# Time for epoch 462 is 7.1090 sec
# Epoch 463, gen_loss: 2.1440, disc_loss: 0.8109
# Time for epoch 463 is 10.7427 sec
# Epoch 464, gen_loss: 2.1544, disc_loss: 0.8142
# Time for epoch 464 is 6.4933 sec
# Epoch 465, gen_loss: 2.2740, disc_loss: 0.7807
# Time for epoch 465 is 7.2933 sec
# Epoch 466, gen_loss: 2.1336, disc_loss: 0.9223
# Time for epoch 466 is 5.9257 sec
# Epoch 467, gen_loss: 2.3598, disc_loss: 0.7528
# Time for epoch 467 is 6.3931 sec
# Epoch 468, gen_loss: 2.2198, disc_loss: 0.8183
# Time for epoch 468 is 9.3966 sec
# Epoch 469, gen_loss: 2.2872, disc_loss: 0.7446
# Time for epoch 469 is 6.3600 sec
# Epoch 470, gen_loss: 2.3599, disc_loss: 0.7448
# Time for epoch 470 is 6.1993 sec
# Epoch 471, gen_loss: 2.2601, disc_loss: 0.8189
# Time for epoch 471 is 6.1490 sec
# Epoch 472, gen_loss: 2.3301, disc_loss: 0.7411
# Time for epoch 472 is 5.8443 sec
# Epoch 473, gen_loss: 2.3997, disc_loss: 0.7163
# Time for epoch 473 is 9.6291 sec
# Epoch 474, gen_loss: 2.3806, disc_loss: 0.6856
# Time for epoch 474 is 6.8579 sec
# Epoch 475, gen_loss: 2.3554, disc_loss: 0.6893
# Time for epoch 475 is 5.9132 sec
# Epoch 476, gen_loss: 2.2980, disc_loss: 0.7620
# Time for epoch 476 is 6.1166 sec
# Epoch 477, gen_loss: 2.2855, disc_loss: 0.7653
# Time for epoch 477 is 6.0564 sec
# Epoch 478, gen_loss: 2.3810, disc_loss: 0.6864
# Time for epoch 478 is 8.9536 sec
# Epoch 479, gen_loss: 2.3686, disc_loss: 0.7615
# Time for epoch 479 is 6.8436 sec
# Epoch 480, gen_loss: 2.4100, disc_loss: 0.6991
# Time for epoch 480 is 5.7944 sec
# Epoch 481, gen_loss: 2.3066, disc_loss: 0.7089
# Time for epoch 481 is 6.1319 sec
# Epoch 482, gen_loss: 2.3850, disc_loss: 0.7201
# Time for epoch 482 is 6.0710 sec
# Epoch 483, gen_loss: 2.2974, disc_loss: 0.8223
# Time for epoch 483 is 5.6420 sec
# Epoch 484, gen_loss: 2.3057, disc_loss: 0.7813
# Time for epoch 484 is 9.5416 sec
# Epoch 485, gen_loss: 2.3769, disc_loss: 0.7524
# Time for epoch 485 is 6.6028 sec
# Epoch 486, gen_loss: 2.3181, disc_loss: 0.7573
# Time for epoch 486 is 6.7436 sec
# Epoch 487, gen_loss: 2.3943, disc_loss: 0.7091
# Time for epoch 487 is 6.5212 sec
# Epoch 488, gen_loss: 2.2913, disc_loss: 0.7859
# Time for epoch 488 is 11.2616 sec
# Epoch 489, gen_loss: 2.3214, disc_loss: 0.7582
# Time for epoch 489 is 7.4482 sec
# Epoch 490, gen_loss: 2.3446, disc_loss: 0.7437
# Time for epoch 490 is 7.2188 sec
# Epoch 491, gen_loss: 2.2780, disc_loss: 0.8166
# Time for epoch 491 is 5.9889 sec
# Epoch 492, gen_loss: 2.5687, disc_loss: 0.6698
# Time for epoch 492 is 7.6530 sec
# Epoch 493, gen_loss: 2.4819, disc_loss: 0.7155
# Time for epoch 493 is 10.6888 sec
# Epoch 494, gen_loss: 2.5078, disc_loss: 0.6655
# Time for epoch 494 is 6.1597 sec
# Epoch 495, gen_loss: 2.4257, disc_loss: 0.7205
# Time for epoch 495 is 5.8088 sec
# Epoch 496, gen_loss: 2.4104, disc_loss: 0.7414
# Time for epoch 496 is 10.2258 sec
# Epoch 497, gen_loss: 2.5126, disc_loss: 0.6356
# Time for epoch 497 is 9.2012 sec
# Epoch 498, gen_loss: 2.3752, disc_loss: 0.6883
# Time for epoch 498 is 5.7079 sec
# Epoch 499, gen_loss: 2.3426, disc_loss: 0.7339
# Time for epoch 499 is 5.9596 sec
# Epoch 500, gen_loss: 2.5813, disc_loss: 0.6452
# Time for epoch 500 is 5.7194 sec

# %% [markdown]
# <h1> Evaluation </h1>
# dataset/testData.pkl is a pandas dataframe containing testing text with attributes 'ID' and 'Captions'.
#
# - 'ID': text ID used to name generated image.
# - 'Captions': text used as condition to generate image.
#
# For each captions, you need to generate inference_ID.png to evaluate quality of generated image. You must name the generated image in this format, otherwise we cannot evaluate your images.

# %% [markdown]
# <h2> Testing Dataset </h2>

# %% [markdown]
# If you change anything during preprocessing of training dataset, you must make sure same operations have be done in testing dataset.

# %%
def testing_data_generator(caption, index):
    caption = tf.cast(caption, tf.float32)
    return caption, index

def testing_dataset_generator(batch_size, data_generator):
    data = pd.read_pickle('./dataset/testData.pkl')
    captions = data['Captions'].values
    caption = []
    for i in range(len(captions)):
        caption.append(captions[i])
    caption = np.asarray(caption)
    caption = caption.astype(int)
    index = data['ID'].values
    index = np.asarray(index)
    
    dataset = tf.data.Dataset.from_tensor_slices((caption, index))
    dataset = dataset.map(data_generator, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.repeat().batch(batch_size)
    
    return dataset

# %%
testing_dataset = testing_dataset_generator(hparas['BATCH_SIZE'], testing_data_generator)

# %%
data = pd.read_pickle('./dataset/testData.pkl')
captions = data['Captions'].values

NUM_TEST = len(captions)
EPOCH_TEST = int(NUM_TEST / hparas['BATCH_SIZE'])

# %% [markdown]
# <h2> Inferece </h2>

# %%
if not os.path.exists('./inference/demo'):
    os.makedirs('./inference/demo')

# %%
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

# %%
def inference(dataset):
    hidden = text_encoder.initialize_hidden_state()
    sample_size = hparas['BATCH_SIZE']
    sample_seed = np.random.normal(loc=0.0, scale=1.0, size=(sample_size, hparas['Z_DIM'])).astype(np.float32)
    
    step = 0
    start = time.time()
    for captions, idx in dataset:
        if step > EPOCH_TEST:
            break
        
        fake_image = test_step(captions, sample_seed, hidden)
        step += 1
        for i in range(hparas['BATCH_SIZE']):
            plt.imsave('./inference/demo/inference_{:04d}.jpg'.format(idx[i]), fake_image[i].numpy()*0.5 + 0.5)
            
    print('Time for inference is {:.4f} sec'.format(time.time()-start))

# %%
latest_ckpt = tf.train.latest_checkpoint(checkpoint_dir)
print("Restoring from:", latest_ckpt)
checkpoint.restore(latest_ckpt)
# Out:
# Restoring from: ./checkpoints/demo/ckpt-10

# %%
inference(testing_dataset)
# Out:
# Time for inference is 5.9873 sec
